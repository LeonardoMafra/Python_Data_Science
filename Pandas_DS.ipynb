# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoMafra/Python_Data_Science/blob/main/Pandas_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importando o Pandas

import pandas as pd
import numpy  as np

# %%
# carregando arquivo para dentreo do colab e fazendo a leitura

from google import colab as cl

file_upload = cl.files.upload()
# Out:
#      <input type="file" id="files-064c1b56-e887-4cf2-ab68-b0ec021b0754" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-064c1b56-e887-4cf2-ab68-b0ec021b0754">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#abrindo arquivo excel com o pandas

df = pd.read_excel('funcionarios.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-482f4fd9fb27> in <cell line: 0>()
#       1 #abrindo arquivo excel com o pandas
#       2
# ----> 3 df = pd.read_excel('funcionarios.xlsx')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
#criando copia do dataframe para trabalhar com a copia em vez do arquivo original

pessoas = df.copy()

# %%
# verificado o tipo do arquivo no Pandas
type(pessoas)

# %%
# USANDO DATAFRAME IMPORTADO DO KAGGLE

# %%
from google import colab as cl

file_upload = cl.files.upload()
# Out:
#      <input type="file" id="files-8b88fa8f-7d44-49de-96b9-88c8879118c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b88fa8f-7d44-49de-96b9-88c8879118c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('HIST_PAINEL_COVIDBR_01jun2020.xlsx')
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
dados_covid = df.copy()

# %%
dados_covid.head() # verificando as primeiras linhas do dataframe
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2020-02-26          9       210147125.0               1           0
# 1  2020-02-27          9       210147125.0               1           0
# 2  2020-02-28          9       210147125.0               1           0
# 3  2020-02-29          9       210147125.0               2           1
# 4  2020-03-01         10       210147125.0               2           0
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos
# ...

# %%
dados_covid.tail() # pegando as ultimas linhas do dataframe
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 142794  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142795  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142796  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142797  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142798  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 142794        Brasília  2020-05-28         22         3015268.0
# 142795        Brasília  2020-05-29         22         3015268.0
# 142796        Brasília  2020-05-30         22         3015268.0
# 142797        Brasília  2020-05-31         23         3015268.0
# 142798        Brasília  2020-06-01         23         3015268.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 142794            8300         539              142            9
# ...

# %%
dados_covid.columns # verificar as colunas do dataframe
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos'],
#       dtype='object')

# %%
dados_covid.dtypes # verificar tipos dos dados
# Out:
# regiao                    object
# estado                    object
# municipio                 object
# coduf                      int64
# codmun                   float64
# codRegiaoSaude           float64
# nomeRegiaoSaude           object
# data                      object
# semanaEpi                  int64
# populacaoTCU2019         float64
# casosAcumulado             int64
# casosNovos                 int64
# obitosAcumulado            int64
# obitosNovos                int64
# Recuperadosnovos         float64
# emAcompanhamentoNovos    float64
# dtype: object

# %%
dados_covid.info() # verificar dados do dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142799 entries, 0 to 142798
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   regiao                 142799 non-null  object
#  1   estado                 142702 non-null  object
#  2   municipio              139850 non-null  object
#  3   coduf                  142799 non-null  int64
#  4   codmun                 140536 non-null  float64
#  5   codRegiaoSaude         139850 non-null  float64
#  6   nomeRegiaoSaude        139850 non-null  object
#  7   data                   142799 non-null  object
#  8   semanaEpi              142799 non-null  int64
#  9   populacaoTCU2019       142113 non-null  float64
#  10  casosAcumulado         142799 non-null  int64
#  11  casosNovos             142799 non-null  int64
#  12  obitosAcumulado        142799 non-null  int64
#  13  obitosNovos            142799 non-null  int64
# ...

# %%
dados_covid.shape # verificar tamanho e colunas do dataframe
# Out:
# (142799, 16)

# %%
#selecionar colunas especificoas

dados_covid[['regiao','municipio','estado','coduf']].head(10),
# Out:
#    regiao municipio estado  coduf
# 0  Brasil       NaN    NaN     76
# 1  Brasil       NaN    NaN     76
# 2  Brasil       NaN    NaN     76
# 3  Brasil       NaN    NaN     76
# 4  Brasil       NaN    NaN     76
# 5  Brasil       NaN    NaN     76
# 6  Brasil       NaN    NaN     76
# 7  Brasil       NaN    NaN     76
# 8  Brasil       NaN    NaN     76
# 9  Brasil       NaN    NaN     76

# %%
# meyodo describe

dados_covid[['casosNovos', 'obitosNovos']].describe()
# Out:
#           casosNovos    obitosNovos
# count  142799.000000  142799.000000
# mean       11.013817       0.634528
# std       248.500980      13.621583
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         1.000000       0.000000
# max     33274.000000    1188.000000

# %%
# verificar quantidade de nulos no dataframe

dados_covid.isna().sum()
dados_covid.isnull().sum()
# Out:
# regiao                        0
# estado                       97
# municipio                  2949
# coduf                         0
# codmun                     2263
# codRegiaoSaude             2949
# nomeRegiaoSaude            2949
# data                          0
# semanaEpi                     0
# populacaoTCU2019            686
# casosAcumulado                0
# casosNovos                    0
# obitosAcumulado               0
# obitosNovos                   0
# Recuperadosnovos         142755
# emAcompanhamentoNovos    142755
# dtype: int64

# %%
#verificar quantos campos unicos tem

dados_covid['regiao'].unique()
# Out:
# array(['Brasil', 'Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste'],
#       dtype=object)

# %%
#filtrar dataframe atravez de um campo

dados_covid[dados_covid['regiao']=='Nordeste'].head(10)
# Out:
#        regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 621  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 622  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 623  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 624  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 625  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 626  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 627  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 628  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 629  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 630  Nordeste     MA       NaN     21     NaN             NaN             NaN
#
#            data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# ...

# %%
#verificando a quantidade de dados  com o shape filtando por coluna

dados_covid[dados_covid['regiao']=='Nordeste'].shape
# Out:
# (50675, 16)

# %%
# filtrar dataframe por uma lista


lista = ['Nordeste', 'Sudeste']


dados_covid[dados_covid['regiao'].isin(lista)]
# Out:
#           regiao estado     municipio  coduf    codmun  codRegiaoSaude  \
# 621     Nordeste     MA           NaN     21       NaN             NaN
# 622     Nordeste     MA           NaN     21       NaN             NaN
# 623     Nordeste     MA           NaN     21       NaN             NaN
# 624     Nordeste     MA           NaN     21       NaN             NaN
# 625     Nordeste     MA           NaN     21       NaN             NaN
# ...          ...    ...           ...    ...       ...             ...
# 107720   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107721   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107722   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107723   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107724   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
dados_covid[dados_covid['municipio']=='Valinhos'].head()
# Out:
#          regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 107092  Sudeste     SP  Valinhos     35  355620.0         35072.0
# 107093  Sudeste     SP  Valinhos     35  355620.0         35072.0
# 107094  Sudeste     SP  Valinhos     35  355620.0         35072.0
# 107095  Sudeste     SP  Valinhos     35  355620.0         35072.0
# 107096  Sudeste     SP  Valinhos     35  355620.0         35072.0
#
#                          nomeRegiaoSaude        data  semanaEpi  \
# 107092  Região Metropolitana de Campinas  2020-03-28         13
# 107093  Região Metropolitana de Campinas  2020-03-29         14
# 107094  Região Metropolitana de Campinas  2020-03-30         14
# 107095  Região Metropolitana de Campinas  2020-03-31         14
# 107096  Região Metropolitana de Campinas  2020-04-01         14
#
#         populacaoTCU2019  casosAcumulado  casosNovos  obitosAcumulado  \
# 107092          129193.0               1           0                0
# ...

# %%
# Filtrar null

dados_covid[(dados_covid['regiao'].isin(lista))]

# %%
# verificando casos onde os casos foram altos

mais_casos = dados_covid.casosNovos > 1000

dados_covid[mais_casos]
# Out:
#          regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 34       Brasil    NaN        NaN     76       NaN             NaN
# 35       Brasil    NaN        NaN     76       NaN             NaN
# 36       Brasil    NaN        NaN     76       NaN             NaN
# 37       Brasil    NaN        NaN     76       NaN             NaN
# 38       Brasil    NaN        NaN     76       NaN             NaN
# ...         ...    ...        ...    ...       ...             ...
# 104996  Sudeste     SP  São Paulo     35  355030.0         35016.0
# 104997  Sudeste     SP  São Paulo     35  355030.0         35016.0
# 104998  Sudeste     SP  São Paulo     35  355030.0         35016.0
# 104999  Sudeste     SP  São Paulo     35  355030.0         35016.0
# 105000  Sudeste     SP  São Paulo     35  355030.0         35016.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 34                 NaN  2020-03-31         14       210147125.0
# ...

# %%
# ordernar por mais casos

dados_covid.sort_values('casosNovos', ascending=False)
# Out:
#          regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 94       Brasil    NaN       NaN     76       NaN             NaN
# 93       Brasil    NaN       NaN     76       NaN             NaN
# 92       Brasil    NaN       NaN     76       NaN             NaN
# 86       Brasil    NaN       NaN     76       NaN             NaN
# 91       Brasil    NaN       NaN     76       NaN             NaN
# ...         ...    ...       ...    ...       ...             ...
# 60717  Nordeste     BA     Itagi     29  291510.0         29015.0
# 60716  Nordeste     BA     Itagi     29  291510.0         29015.0
# 60715  Nordeste     BA     Itagi     29  291510.0         29015.0
# 60714  Nordeste     BA     Itagi     29  291510.0         29015.0
# 71399   Sudeste     MG     Ipaba     31  313115.0         31027.0
#
#       nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 94                NaN  2020-05-30         22       210147125.0
# ...

# %%
# comandos para realizar limpezas ou remover nullo

# %%
# remover linha que contenha pelo menos um valor nulo

df_sem_nulos_linha = df.dropna()


# remover colunas que contanham pelo menos um valor nulo

df_sem_nulos_colunas = df.dropna(axis=1)


# preecher varios nulos com valor especifico ( por exemplo , zero)

df_preechido_zero = df.fillna(0)

# preecher valores nulos = df.fillna('')
